# %%
import enigmatoolbox
import numpy as np
from enigmatoolbox.utils.parcellation import parcel_to_surface
from enigmatoolbox.plotting import plot_cortical
import pandas as pd
from scipy.stats import zscore, spearmanr
from enigmatoolbox.datasets import load_example_data
from enigmatoolbox.utils.useful import zscore_matrix

# %%
# Load all example data from an individual site
cov, metr1_SubVol, metr2_CortThick, metr3_CortSurf = load_example_data()
group = cov['Dx'].to_list()
controlCode = 0
CT_z = zscore_matrix(metr2_CortThick.iloc[:, 1:-5], group, controlCode)
CT_z_mean = CT_z.iloc[cov[cov['SDx'] == 3].index, :].mean(axis=0)

# %%
#SCHAEFER 100
data=pd.read_csv('/Users/charlie/Desktop/my_projects/neurotransmitter/R/parcellate/results/cohens_d_transp_Schaeffer_100.csv', header = None)
data = data.drop(0)
data = data.stack().reset_index(drop=True)[1::2].reset_index(drop=True).astype(float)
plot_cortical(array_name=parcel_to_surface(data, 'schaefer_100_fsa5'), surface_name="fsa5",
              background=(100,100,100), size=(8000, 4000),
              cmap='RdBu', color_bar=True, color_range=(-1.1, 0.6),screenshot=True, 
              filename="/Users/charlie/Desktop/my_projects/neurotransmitter/figures/brain_surface/results/track_node_Schaeffer_100.png" )

# %%
### PARCELLATIONS NODE
#CHANGE TO PDF

# DK 68 
data=pd.read_csv('/Users/charlie/Desktop/my_projects/neurotransmitter/R/parcellate/results/cohens_d_transp_DK68.csv', header = None)
data = data.drop(0)
data = data.stack().reset_index(drop=True)[1::2].reset_index(drop=True).astype(float)
data.index = CT_z_mean.index
plot_cortical(array_name=parcel_to_surface(data, 'aparc_fsa5'), surface_name="fsa5",
              background=(100,100,100), size=(8000, 4000),
              cmap='RdBu', color_bar=True, color_range=(-1.1, 0.7),screenshot=True, 
              filename="/Users/charlie/Desktop/my_projects/neurotransmitter/figures/brain_surface/results/track_node_DK68.png" )




#SCHAEFER 100
data=pd.read_csv('/Users/charlie/Desktop/my_projects/neurotransmitter/R/parcellate/results/cohens_d_transp_Schaeffer_100.csv', header = None)
data = data.drop(0)
data = data.stack().reset_index(drop=True)[1::2].reset_index(drop=True).astype(float)
plot_cortical(array_name=parcel_to_surface(data, 'schaefer_100_fsa5'), surface_name="fsa5",
              background=(100,100,100), size=(8000, 4000),
              cmap='RdBu', color_bar=True, color_range=(-1.1, 0.7),screenshot=True, 
              filename="/Users/charlie/Desktop/my_projects/neurotransmitter/figures/brain_surface/results/track_node_Schaeffer_100.png" )


#SCHAEFER 200
data=pd.read_csv('/Users/charlie/Desktop/my_projects/neurotransmitter/R/parcellate/results/cohens_d_transp_Schaeffer_200.csv', header = None)
data = data.drop(0)
data = data.stack().reset_index(drop=True)[1::2].reset_index(drop=True).astype(float)
plot_cortical(array_name=parcel_to_surface(data, 'schaefer_200_fsa5'), surface_name="fsa5",
              background=(100,100,100), size=(8000, 4000),
              cmap='RdBu', color_bar=True, color_range=(-1.1, 0.7),screenshot=True, 
              filename="/Users/charlie/Desktop/my_projects/neurotransmitter/figures/brain_surface/results/track_node_Schaeffer_200.png" )



#SCHAEFER 400
data=pd.read_csv('/Users/charlie/Desktop/my_projects/neurotransmitter/R/parcellate/results/cohens_d_transp_Schaeffer_400.csv', header = None)
data = data.drop(0)
data = data.stack().reset_index(drop=True)[1::2].reset_index(drop=True).astype(float)
plot_cortical(array_name=parcel_to_surface(data, 'schaefer_400_fsa5'), surface_name="fsa5",
              background=(100,100,100), size=(8000, 4000),
              cmap='RdBu', color_bar=True, color_range=(-1.1, 0.7),screenshot=True, 
              filename="/Users/charlie/Desktop/my_projects/neurotransmitter/figures/brain_surface/results/track_node_Schaeffer_400.png" )

# %%
### PARCELLATIONS NODE
#CHANGE TO PDF

# DK 68 
data=pd.read_csv('/Users/charlie/Desktop/my_projects/neurotransmitter/R/parcellate/results/cohens_d_transp_DK68.csv', header = None)
data = data.drop(0)
data = data.stack().reset_index(drop=True)[1::2].reset_index(drop=True).astype(float)
data.index = CT_z_mean.index
plot_cortical(array_name=parcel_to_surface(data, 'aparc_conte69'), surface_name="conte69",
              background=(100,100,100), size=(8000, 4000),
              cmap='RdBu', color_bar=True, color_range=(-1.1, 0.7),screenshot=True, 
              filename="/Users/charlie/Desktop/my_projects/neurotransmitter/figures/brain_surface/results/track_node_DK68_conte69.png" )





#SCHAEFFER 100
data=pd.read_csv('/Users/charlie/Desktop/my_projects/neurotransmitter/R/parcellate/results/cohens_d_transp_Schaeffer_100.csv', header = None)
data = data.drop(0)
data = data.stack().reset_index(drop=True)[1::2].reset_index(drop=True).astype(float)
plot_cortical(array_name=parcel_to_surface(data, 'schaefer_100_conte69'), surface_name="conte69",
              background=(100,100,100), size=(8000, 4000),
              cmap='RdBu', color_bar=True, color_range=(-1.1, 0.7),screenshot=True, 
              filename="/Users/charlie/Desktop/my_projects/neurotransmitter/figures/brain_surface/results/track_node_Schaeffer_100_conte69.png" )


#SCHAEFFER 200
data=pd.read_csv('/Users/charlie/Desktop/my_projects/neurotransmitter/R/parcellate/results/cohens_d_transp_Schaeffer_200.csv', header = None)
data = data.drop(0)
data = data.stack().reset_index(drop=True)[1::2].reset_index(drop=True).astype(float)
plot_cortical(array_name=parcel_to_surface(data, 'schaefer_200_conte69'), surface_name="conte69",
              background=(100,100,100), size=(8000, 4000),
              cmap='RdBu', color_bar=True, color_range=(-1.1, 0.7),screenshot=True, 
              filename="/Users/charlie/Desktop/my_projects/neurotransmitter/figures/brain_surface/results/track_node_Schaeffer_200_conte69.png" )



#SCHAEFFER 400
data=pd.read_csv('/Users/charlie/Desktop/my_projects/neurotransmitter/R/parcellate/results/cohens_d_transp_Schaeffer_400.csv', header = None)
data = data.drop(0)
data = data.stack().reset_index(drop=True)[1::2].reset_index(drop=True).astype(float)
plot_cortical(array_name=parcel_to_surface(data, 'schaefer_400_conte69'), surface_name="conte69",
              background=(100,100,100), size=(8000, 4000),
              cmap='RdBu', color_bar=True, color_range=(-1.1, 0.7),screenshot=True, 
              filename="/Users/charlie/Desktop/my_projects/neurotransmitter/figures/brain_surface/results/track_node_Schaeffer_400_conte69.png" )
